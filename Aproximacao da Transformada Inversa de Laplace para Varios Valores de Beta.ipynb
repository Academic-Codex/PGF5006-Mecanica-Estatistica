# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib widget

# Parâmetros para a aproximação da função delta via exponencial
x = np.linspace(-5, 5, 1000)  # Eixo x
beta_vals = np.linspace(0.1, 2, 30)  # Vários valores de beta

# Preparar o grid para o gráfico 3D
X, B = np.meshgrid(x, beta_vals)

# Função exponencial para a transformada de Laplace inversa
delta_approx_3D = np.exp(-B * np.abs(X))

# Criar o gráfico 3D interativo
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plotar a superfície
surf = ax.plot_surface(X, B, delta_approx_3D, cmap='viridis')

# Adicionar rótulos e título
ax.set_title("Aproximação da Transformada Inversa de Laplace para Vários Valores de Beta")
ax.set_xlabel('x')
ax.set_ylabel('Beta')
ax.set_zlabel('Intensidade')

# Adicionar barra de cores para representar a intensidade
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

# Garantir que o backend seja interativo
plt.ion()

# Mostrar o gráfico com interatividade
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
